# %%
import sys, os
sys.path.append(os.path.abspath("../src"))
from evaluators.intent_eval import evaluate_intents, plot_confusion_matrix
results = evaluate_intents('../data/sample_intents.json')
print(results['report'])
plot_confusion_matrix(results['confusion_matrix'], results['labels'])
# Out:
# {'billing': {'precision': 1.0, 'recall': 0.5, 'f1-score': 0.6666666666666666, 'support': 2.0}, 'general': {'precision': 0.5, 'recall': 1.0, 'f1-score': 0.6666666666666666, 'support': 1.0}, 'tech_support': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 1.0}, 'accuracy': 0.75, 'macro avg': {'precision': 0.8333333333333334, 'recall': 0.8333333333333334, 'f1-score': 0.7777777777777777, 'support': 4.0}, 'weighted avg': {'precision': 0.875, 'recall': 0.75, 'f1-score': 0.75, 'support': 4.0}}
